# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # Import CMUdict

# %%
# download CMUdict from https://github.com/Alexir/CMUdict/blob/master/cmudict-0.7b 
# and trimmed out the punctuations
cmu = pd.read_csv('02_cmudict-07b', names =['cmu'])
cmu[['word','cmu_pronunciation']] = cmu["cmu"].str.split(" ", 1, expand=True)
cmu[1:10]
# Out:
#                                              cmu    word  \
# 1                                      A(1)  EY1    A(1)
# 2                                     A'S  EY1 Z     A'S
# 3                                        A.  EY1      A.
# 4                                    A.'S  EY1 Z    A.'S
# 5                                A.D.  EY2 D IY1    A.D.
# 6                                A.M.  EY2 EH1 M    A.M.
# 7                                     A.S  EY1 Z     A.S
# 8  A42128  EY1 F AO1 R T UW1 W AH1 N T UW1 EY1 T  A42128
# 9                                    AA  EY2 EY1      AA
#
#                         cmu_pronunciation
# 1                                     EY1
# 2                                   EY1 Z
# 3                                     EY1
# 4                                   EY1 Z
# 5                               EY2 D IY1
# 6                               EY2 EH1 M
# 7                                   EY1 Z
# 8   EY1 F AO1 R T UW1 W AH1 N T UW1 EY1 T
# 9                                 EY2 EY1

# %%
cmu_dict = cmu[["word", "cmu_pronunciation"]]
cmu_dict.head()
# Out:
#    word cmu_pronunciation
# 0     A               AH0
# 1  A(1)               EY1
# 2   A'S             EY1 Z
# 3    A.               EY1
# 4  A.'S             EY1 Z

# %%
cmudict = cmu_dict.set_index('word').T.to_dict('list')

# %% [markdown]
# # input sentences

# %%
df_input = pd.read_excel('02_input_text.xlsx')
df_input
# Out:
#    id                                           sentence
# 0   1  Those     promises have fallen apart. India, e...
# 1   2  He has come under criticism for departing to L...
# 2   3  2021 He said he would return to India when he ...
# 3   4  He   told a British newspaper he had received ...
# 4   5  When he.      returns to India, he will travel...

# %%
#data cleaning
import re
df_input["clean"] = df_input["sentence"].fillna("")
df_input["clean"] = df_input["clean"].apply(lambda x: x.lower())
df_input['clean'] = df_input['clean'].map(lambda x: re.sub('[,\.!?()‘\'"“”’]', '', str(x))) 
df_input['clean'] = df_input['clean'].str.replace(r'\s+'," ", regex=True)
df_input["clean"] = df_input["clean"].str.strip()
df_input
# Out:
#    id                                           sentence  \
# 0   1  Those     promises have fallen apart. India, e...
# 1   2  He has come under criticism for departing to L...
# 2   3  2021 He said he would return to India when he ...
# 3   4  He   told a British newspaper he had received ...
# 4   5  When he.      returns to India, he will travel...
#
#                                                clean
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
# 2  2021 he said he would return to india when he ...
# 3  he told a british newspaper he had received th...
# 4  when he returns to india he will travel with g...

# %%
df_input["sep"] = df_input["clean"].str.split(" ")
df_input.head()
# Out:
#    id                                           sentence  \
# 0   1  Those     promises have fallen apart. India, e...
# 1   2  He has come under criticism for departing to L...
# 2   3  2021 He said he would return to India when he ...
# 3   4  He   told a British newspaper he had received ...
# 4   5  When he.      returns to India, he will travel...
#
#                                                clean  \
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
# 2  2021 he said he would return to india when he ...
# 3  he told a british newspaper he had received th...
# 4  when he returns to india he will travel with g...
#
#                                                  sep
# 0  [those, promises, have, fallen, apart, india, ...
# 1  [he, has, come, under, criticism, for, departi...
# 2  [2021, he, said, he, would, return, to, india,...
# 3  [he, told, a, british, newspaper, he, had, rec...
# 4  [when, he, returns, to, india, he, will, trave...

# %%
# convert numbers to words
# !pip install num2words
import num2words
def convert_num_to_words(utterance):
    utterance = ' '.join([num2words.num2words(i) if i.isdigit() else i for i in utterance])
    return utterance

# %%
df_input["words"] = df_input['sep'].apply(convert_num_to_words)
df_input['words'] = df_input['words'].map(lambda x: re.sub('-', ' ', str(x))) # numbers that have '-'
df_input
# Out:
#    id                                           sentence  \
# 0   1  Those     promises have fallen apart. India, e...
# 1   2  He has come under criticism for departing to L...
# 2   3  2021 He said he would return to India when he ...
# 3   4  He   told a British newspaper he had received ...
# 4   5  When he.      returns to India, he will travel...
#
#                                                clean  \
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
# 2  2021 he said he would return to india when he ...
# 3  he told a british newspaper he had received th...
# 4  when he returns to india he will travel with g...
#
#                                                  sep  \
# 0  [those, promises, have, fallen, apart, india, ...
# 1  [he, has, come, under, criticism, for, departi...
# 2  [2021, he, said, he, would, return, to, india,...
# 3  [he, told, a, british, newspaper, he, had, rec...
# 4  [when, he, returns, to, india, he, will, trave...
#
#                                                words
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
# 2  two thousand and twenty one he said he would r...
# 3  he told a british newspaper he had received th...
# 4  when he returns to india he will travel with g...

# %% [markdown]
# # Count Syllables

# %%
df = df_input.copy()
df.head(2)
# Out:
#    id                                           sentence  \
# 0   1  Those     promises have fallen apart. India, e...
# 1   2  He has come under criticism for departing to L...
#
#                                                clean  \
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
#
#                                                  sep  \
# 0  [those, promises, have, fallen, apart, india, ...
# 1  [he, has, come, under, criticism, for, departi...
#
#                                                words
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...

# %%
df['list'] = df['words'].apply(lambda x: x.upper())
df['list'] = df['list'].str.split(" ")
df['list'].fillna('empty', inplace=True)
df.head()
# Out:
#    id                                           sentence  \
# 0   1  Those     promises have fallen apart. India, e...
# 1   2  He has come under criticism for departing to L...
# 2   3  2021 He said he would return to India when he ...
# 3   4  He   told a British newspaper he had received ...
# 4   5  When he.      returns to India, he will travel...
#
#                                                clean  \
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
# 2  2021 he said he would return to india when he ...
# 3  he told a british newspaper he had received th...
# 4  when he returns to india he will travel with g...
#
#                                                  sep  \
# 0  [those, promises, have, fallen, apart, india, ...
# 1  [he, has, come, under, criticism, for, departi...
# 2  [2021, he, said, he, would, return, to, india,...
# 3  [he, told, a, british, newspaper, he, had, rec...
# 4  [when, he, returns, to, india, he, will, trave...
#
#                                                words  \
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
# 2  two thousand and twenty one he said he would r...
# 3  he told a british newspaper he had received th...
# 4  when he returns to india he will travel with g...
#
#                                                 list
# 0  [THOSE, PROMISES, HAVE, FALLEN, APART, INDIA, ...
# 1  [HE, HAS, COME, UNDER, CRITICISM, FOR, DEPARTI...
# 2  [TWO, THOUSAND, AND, TWENTY, ONE, HE, SAID, HE...
# 3  [HE, TOLD, A, BRITISH, NEWSPAPER, HE, HAD, REC...
# 4  [WHEN, HE, RETURNS, TO, INDIA, HE, WILL, TRAVE...

# %%
# extract words that are not included in the CMUdict
def extract_nocmu(data):
    no_list = []
    for word in data:
        if word not in cmudict:
            no_list.append(word)
    return no_list

# %%
df["No_CMU_words"] = df["list"].apply(extract_nocmu)
df.head()
# Out:
#    id                                           sentence  \
# 0   1  Those     promises have fallen apart. India, e...
# 1   2  He has come under criticism for departing to L...
# 2   3  2021 He said he would return to India when he ...
# 3   4  He   told a British newspaper he had received ...
# 4   5  When he.      returns to India, he will travel...
#
#                                                clean  \
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
# 2  2021 he said he would return to india when he ...
# 3  he told a british newspaper he had received th...
# 4  when he returns to india he will travel with g...
#
#                                                  sep  \
# 0  [those, promises, have, fallen, apart, india, ...
# 1  [he, has, come, under, criticism, for, departi...
# 2  [2021, he, said, he, would, return, to, india,...
# 3  [he, told, a, british, newspaper, he, had, rec...
# 4  [when, he, returns, to, india, he, will, trave...
#
#                                                words  \
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
# 2  two thousand and twenty one he said he would r...
# 3  he told a british newspaper he had received th...
# 4  when he returns to india he will travel with g...
#
#                                                 list   No_CMU_words
# 0  [THOSE, PROMISES, HAVE, FALLEN, APART, INDIA, ...  [CORONAVIRUS]
# 1  [HE, HAS, COME, UNDER, CRITICISM, FOR, DEPARTI...             []
# 2  [TWO, THOUSAND, AND, TWENTY, ONE, HE, SAID, HE...             []
# 3  [HE, TOLD, A, BRITISH, NEWSPAPER, HE, HAD, REC...       [INDIAS]
# 4  [WHEN, HE, RETURNS, TO, INDIA, HE, WILL, TRAVE...             []

# %%
for sub in df['list']:
    for i, word in enumerate(sub):
        if word in cmudict:
            sub[i] = cmudict[word]
df.head(2)
# Out:
#    id                                           sentence  \
# 0   1  Those     promises have fallen apart. India, e...
# 1   2  He has come under criticism for departing to L...
#
#                                                clean  \
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
#
#                                                  sep  \
# 0  [those, promises, have, fallen, apart, india, ...
# 1  [he, has, come, under, criticism, for, departi...
#
#                                                words  \
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
#
#                                                 list   No_CMU_words
# 0  [[ DH OW1 Z], [ P R AA1 M AH0 S AH0 Z], [ HH A...  [CORONAVIRUS]
# 1  [[ HH IY1], [ HH AE1 Z], [ K AH1 M], [ AH1 N D...             []

# %%
# The following code is copied from https://datascience.stackexchange.com/questions/23376/how-to-get-the-number-of-syllables-in-a-word

import re

VOWEL_RUNS = re.compile("[aeiouy]+", flags=re.I)  # re.IGNORECASE
EXCEPTIONS = re.compile(
    # fixes trailing e issues:
    # smite, scared
    "[^aeiou]e[sd]?$|"
    # fixes adverbs:
    # nicely
    + "[^e]ely$",
    flags=re.I
)

ADDITIONAL = re.compile(
    # fixes incorrect subtractions from exceptions:
    # smile, scarred, raises, fated
    "[^aeioulr][lr]e[sd]?$|[csgz]es$|[td]ed$|"
    # fixes miscellaneous issues:
    # flying, piano, video, prism, fire, evaluate
    + ".y[aeiou]|ia(?!n$)|eo|ism$|[^aeiou]ire$|[^gq]ua",
    flags=re.I
)

def count_syllables(word):
    vowel_runs = len(VOWEL_RUNS.findall(word))
    exceptions = len(EXCEPTIONS.findall(word))
    additional = len(ADDITIONAL.findall(word))
    return max(1, vowel_runs - exceptions + additional)

# %%
for sub in df['No_CMU_words']:
    for i, word in enumerate(sub):
        sub[i]  = count_syllables(word)
df
# Out:
#    id                                           sentence  \
# 0   1  Those     promises have fallen apart. India, e...
# 1   2  He has come under criticism for departing to L...
# 2   3  2021 He said he would return to India when he ...
# 3   4  He   told a British newspaper he had received ...
# 4   5  When he.      returns to India, he will travel...
#
#                                                clean  \
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
# 2  2021 he said he would return to india when he ...
# 3  he told a british newspaper he had received th...
# 4  when he returns to india he will travel with g...
#
#                                                  sep  \
# 0  [those, promises, have, fallen, apart, india, ...
# 1  [he, has, come, under, criticism, for, departi...
# 2  [2021, he, said, he, would, return, to, india,...
# 3  [he, told, a, british, newspaper, he, had, rec...
# 4  [when, he, returns, to, india, he, will, trave...
#
#                                                words  \
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
# 2  two thousand and twenty one he said he would r...
# 3  he told a british newspaper he had received th...
# 4  when he returns to india he will travel with g...
#
#                                                 list No_CMU_words
# 0  [[ DH OW1 Z], [ P R AA1 M AH0 S AH0 Z], [ HH A...          [5]
# 1  [[ HH IY1], [ HH AE1 Z], [ K AH1 M], [ AH1 N D...           []
# 2  [[ T UW1], [ TH AW1 Z AH0 N D], [ AH0 N D], [ ...           []
# 3  [[ HH IY1], [ T OW1 L D], [ AH0], [ B R IH1 T ...          [3]
# 4  [[ W EH1 N], [ HH IY1], [ R IH0 T ER1 N Z], [ ...           []

# %%
df['ARPAsent'] = df['list'].astype(str).str.replace('\[|\]|\'', '')
df.head()
# Out:
# /Users/yk/opt/anaconda3/envs/cmu/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
#    id                                           sentence  \
# 0   1  Those     promises have fallen apart. India, e...
# 1   2  He has come under criticism for departing to L...
# 2   3  2021 He said he would return to India when he ...
# 3   4  He   told a British newspaper he had received ...
# 4   5  When he.      returns to India, he will travel...
#
#                                                clean  \
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
# 2  2021 he said he would return to india when he ...
# 3  he told a british newspaper he had received th...
# 4  when he returns to india he will travel with g...
#
#                                                  sep  \
# 0  [those, promises, have, fallen, apart, india, ...
# 1  [he, has, come, under, criticism, for, departi...
# 2  [2021, he, said, he, would, return, to, india,...
# 3  [he, told, a, british, newspaper, he, had, rec...
# 4  [when, he, returns, to, india, he, will, trave...
#
#                                                words  \
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
# 2  two thousand and twenty one he said he would r...
# 3  he told a british newspaper he had received th...
# 4  when he returns to india he will travel with g...
#
#                                                 list No_CMU_words  \
# 0  [[ DH OW1 Z], [ P R AA1 M AH0 S AH0 Z], [ HH A...          [5]
# 1  [[ HH IY1], [ HH AE1 Z], [ K AH1 M], [ AH1 N D...           []
# 2  [[ T UW1], [ TH AW1 Z AH0 N D], [ AH0 N D], [ ...           []
# 3  [[ HH IY1], [ T OW1 L D], [ AH0], [ B R IH1 T ...          [3]
# 4  [[ W EH1 N], [ HH IY1], [ R IH0 T ER1 N Z], [ ...           []
#
#                                             ARPAsent
# 0   DH OW1 Z,  P R AA1 M AH0 S AH0 Z,  HH AE1 V, ...
# 1   HH IY1,  HH AE1 Z,  K AH1 M,  AH1 N D ER0,  K...
# 2   T UW1,  TH AW1 Z AH0 N D,  AH0 N D,  T W EH1 ...
# 3   HH IY1,  T OW1 L D,  AH0,  B R IH1 T IH0 SH, ...
# 4   W EH1 N,  HH IY1,  R IH0 T ER1 N Z,  T UW1,  ...

# %%
def count_digits(string):
    return sum(item.isdigit() for item in string)

# %%
df['ARPAcnt'] = df['ARPAsent'].apply(count_digits)
df.head()
# Out:
#    id                                           sentence  \
# 0   1  Those     promises have fallen apart. India, e...
# 1   2  He has come under criticism for departing to L...
# 2   3  2021 He said he would return to India when he ...
# 3   4  He   told a British newspaper he had received ...
# 4   5  When he.      returns to India, he will travel...
#
#                                                clean  \
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
# 2  2021 he said he would return to india when he ...
# 3  he told a british newspaper he had received th...
# 4  when he returns to india he will travel with g...
#
#                                                  sep  \
# 0  [those, promises, have, fallen, apart, india, ...
# 1  [he, has, come, under, criticism, for, departi...
# 2  [2021, he, said, he, would, return, to, india,...
# 3  [he, told, a, british, newspaper, he, had, rec...
# 4  [when, he, returns, to, india, he, will, trave...
#
#                                                words  \
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
# 2  two thousand and twenty one he said he would r...
# 3  he told a british newspaper he had received th...
# 4  when he returns to india he will travel with g...
#
#                                                 list No_CMU_words  \
# 0  [[ DH OW1 Z], [ P R AA1 M AH0 S AH0 Z], [ HH A...          [5]
# 1  [[ HH IY1], [ HH AE1 Z], [ K AH1 M], [ AH1 N D...           []
# 2  [[ T UW1], [ TH AW1 Z AH0 N D], [ AH0 N D], [ ...           []
# 3  [[ HH IY1], [ T OW1 L D], [ AH0], [ B R IH1 T ...          [3]
# 4  [[ W EH1 N], [ HH IY1], [ R IH0 T ER1 N Z], [ ...           []
#
#                                             ARPAsent  ARPAcnt
# 0   DH OW1 Z,  P R AA1 M AH0 S AH0 Z,  HH AE1 V, ...       48
# 1   HH IY1,  HH AE1 Z,  K AH1 M,  AH1 N D ER0,  K...       31
# 2   T UW1,  TH AW1 Z AH0 N D,  AH0 N D,  T W EH1 ...       28
# 3   HH IY1,  T OW1 L D,  AH0,  B R IH1 T IH0 SH, ...       37
# 4   W EH1 N,  HH IY1,  R IH0 T ER1 N Z,  T UW1,  ...       20

# %%
df['NUMsum'] = df['No_CMU_words'].apply(sum)
df['Total Syllable_CMU'] = df['ARPAcnt'] + df['NUMsum']
df.to_excel('syllable_cmu.xlsx')
df
# Out:
#    id                                           sentence  \
# 0   1  Those     promises have fallen apart. India, e...
# 1   2  He has come under criticism for departing to L...
# 2   3  2021 He said he would return to India when he ...
# 3   4  He   told a British newspaper he had received ...
# 4   5  When he.      returns to India, he will travel...
#
#                                                clean  \
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
# 2  2021 he said he would return to india when he ...
# 3  he told a british newspaper he had received th...
# 4  when he returns to india he will travel with g...
#
#                                                  sep  \
# 0  [those, promises, have, fallen, apart, india, ...
# 1  [he, has, come, under, criticism, for, departi...
# 2  [2021, he, said, he, would, return, to, india,...
# 3  [he, told, a, british, newspaper, he, had, rec...
# 4  [when, he, returns, to, india, he, will, trave...
#
#                                                words  \
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
# 2  two thousand and twenty one he said he would r...
# 3  he told a british newspaper he had received th...
# 4  when he returns to india he will travel with g...
#
#                                                 list No_CMU_words  \
# 0  [[ DH OW1 Z], [ P R AA1 M AH0 S AH0 Z], [ HH A...          [5]
# 1  [[ HH IY1], [ HH AE1 Z], [ K AH1 M], [ AH1 N D...           []
# 2  [[ T UW1], [ TH AW1 Z AH0 N D], [ AH0 N D], [ ...           []
# 3  [[ HH IY1], [ T OW1 L D], [ AH0], [ B R IH1 T ...          [3]
# 4  [[ W EH1 N], [ HH IY1], [ R IH0 T ER1 N Z], [ ...           []
#
#                                             ARPAsent  ARPAcnt  NUMsum  \
# 0   DH OW1 Z,  P R AA1 M AH0 S AH0 Z,  HH AE1 V, ...       48       5
# 1   HH IY1,  HH AE1 Z,  K AH1 M,  AH1 N D ER0,  K...       31       0
# 2   T UW1,  TH AW1 Z AH0 N D,  AH0 N D,  T W EH1 ...       28       0
# 3   HH IY1,  T OW1 L D,  AH0,  B R IH1 T IH0 SH, ...       37       3
# 4   W EH1 N,  HH IY1,  R IH0 T ER1 N Z,  T UW1,  ...       20       0
#
#    Total Syllable_CMU
# 0                  53
# 1                  31
# 2                  28
# 3                  40
# 4                  20

# %%
# this can be done with the "syllables" library, but the performance is different.
import syllables 
df["syllables"] = df["words"].apply(syllables.estimate)
df.to_excel('syllables_library.xlsx', encoding = 'utf-8')
df
# Out:
#    id                                           sentence  \
# 0   1  Those     promises have fallen apart. India, e...
# 1   2  He has come under criticism for departing to L...
# 2   3  2021 He said he would return to India when he ...
# 3   4  He   told a British newspaper he had received ...
# 4   5  When he.      returns to India, he will travel...
#
#                                                clean  \
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
# 2  2021 he said he would return to india when he ...
# 3  he told a british newspaper he had received th...
# 4  when he returns to india he will travel with g...
#
#                                                  sep  \
# 0  [those, promises, have, fallen, apart, india, ...
# 1  [he, has, come, under, criticism, for, departi...
# 2  [2021, he, said, he, would, return, to, india,...
# 3  [he, told, a, british, newspaper, he, had, rec...
# 4  [when, he, returns, to, india, he, will, trave...
#
#                                                words  \
# 0  those promises have fallen apart india engulfe...
# 1  he has come under criticism for departing to l...
# 2  two thousand and twenty one he said he would r...
# 3  he told a british newspaper he had received th...
# 4  when he returns to india he will travel with g...
#
#                                                 list No_CMU_words  \
# 0  [[ DH OW1 Z], [ P R AA1 M AH0 S AH0 Z], [ HH A...          [5]
# 1  [[ HH IY1], [ HH AE1 Z], [ K AH1 M], [ AH1 N D...           []
# 2  [[ T UW1], [ TH AW1 Z AH0 N D], [ AH0 N D], [ ...           []
# 3  [[ HH IY1], [ T OW1 L D], [ AH0], [ B R IH1 T ...          [3]
# 4  [[ W EH1 N], [ HH IY1], [ R IH0 T ER1 N Z], [ ...           []
#
#                                             ARPAsent  ARPAcnt  NUMsum  \
# 0   DH OW1 Z,  P R AA1 M AH0 S AH0 Z,  HH AE1 V, ...       48       5
# 1   HH IY1,  HH AE1 Z,  K AH1 M,  AH1 N D ER0,  K...       31       0
# 2   T UW1,  TH AW1 Z AH0 N D,  AH0 N D,  T W EH1 ...       28       0
# 3   HH IY1,  T OW1 L D,  AH0,  B R IH1 T IH0 SH, ...       37       3
# 4   W EH1 N,  HH IY1,  R IH0 T ER1 N Z,  T UW1,  ...       20       0
#
#    Total Syllable_CMU  syllables
# 0                  53         60
# 1                  31         31
# 2                  28         30
# 3                  40         42
# 4                  20         21

# %%
#end.
